# %%
import ROOT
import numpy as np
import root_numpy as rnp
from plotly.offline import init_notebook_mode, iplot

# %%
import plotly 
plotly.tools.set_credentials_file(username='cdesio88', api_key='qhPfEEFgqcHRbYWB17Yc')

# %%
event_files_numu = ["Xy_files/Xy_numu_"+str(i+1)+"_sel5_doms.npz" for i in range(100)]
event_files_nue = ["Xy_files/Xy_nue_"+str(i+1)+"_sel5_doms.npz" for i in range(100)]
event_files_train = ["train_test_files/Xy_train"+str(i+1)+"_sel5_updown.npz" for i in range(100)]
event_files_numu_upgoing = ["Xy_files/updown/Xy_numu_"+str(i+1)+"_sel5_doms_up.npz" for i in range(100)]

# %%
def load_X(evt_file):
    return np.load(evt_file)["x"]

# %%
X = load_X(event_files_numu_upgoing[0])

# %%
def plot_lattice_detector():
    i=[]
    j=[]
    k=[]
    for ii,x in enumerate(range(-300,1100,90)):
        for jj,y in enumerate(np.arange(-550,550, 45*np.sqrt(3))):
            for kk,z in enumerate(range(98,712,36)):
                i.append(ii)
                j.append(jj)
                k.append(kk)
            x-= 45
    l_i = np.asarray(i)
    l_j = np.asarray(j)
    l_k = np.asarray(k)


    arr = []
    for i,j,k in zip(l_i,l_j,l_k):
        arr.append((i,j,k))
    lol = np.asarray(arr)
    return lol

def plot_x_evt(evt):
    ggg = np.sum(X[evt], axis=0)
    hhh = np.nonzero(ggg)
    ax.scatter(hhh[0][0], hhh[1][0],hhh[2][0], alpha = 0.9, color='blue')
    for (i,j,k) in zip(hhh[0][1:],hhh[1][1:],hhh[2][1:]):
        ax.scatter(i,j,k, alpha=0.9, color='red')
    return

# %%
gen_evt = (i for i in range(X.shape[0]))

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(lol[:,0], lol[:,1], lol[:,2], alpha=0.2)
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(30, 60)

plot_x_evt(3)
plt.show()
