# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
i=[]
j=[]
k=[]
for ii,x in enumerate(range(-300,1100,90)):
    for jj,y in enumerate(np.arange(-550,550, 45*np.sqrt(3))):
        for kk,z in enumerate(range(98,712,36)):
            i.append(ii)
            j.append(jj)
            k.append(kk)
        x-= 45
l_i = np.asarray(i)
l_j = np.asarray(j)
l_k = np.asarray(k)


arr = []
for i,j,k in zip(l_i,l_j,l_k):
    arr.append((i,j,k))
lol = np.asarray(arr)

# %%
Xy_numu = np.load("/data/km3net/Xy_multi_data_files/train_test_files/numu_nue_stratified_labels/Xy_test1_sel5_doms.npz")
Xy_nue = np.load("/data/km3net/Xy_multi_data_files/Xy_nue_1_sel5_doms.npz")

# %%
X_numu = Xy_numu["x"]
y_numu = Xy_numu["y"]
X_nue = Xy_nue["x"]
y_nue = Xy_nue["y"]

# %%
np.nonzero(np.sum(X_numu[0], axis=0))[1]
# Out:
# array([7, 6, 7, 7, 7, 7, 7, 7, 7, 8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 8, 8, 8,
#        8, 8, 9, 8])

# %%
def plot_x_evt(evt):
    ggg = np.sum(X_numu[evt], axis=0)
    hhh = np.nonzero(ggg)
    print(y_numu[evt])
    return ax.scatter(hhh[0],hhh[1],hhh[2], alpha=0.9, s=100)

# %%
gen = (i for i in range(X_numu.shape[0]))

# %%
% matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(14,10))
ax = Axes3D(fig)

ax.scatter(lol[:,0], lol[:,1], lol[:,2], alpha=0.2, s=100)
#for evt in wrong_class_evt_numu:
#    plot_x_evt(evt)
evt=next(gen)
plot_x_evt(evt)
print(evt)
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(30, 60)
plt.show()
# Out:
# 0
# 29

# %%
% matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,8))
ax = Axes3D(fig)

ax.scatter(lol[:,0], lol[:,1], lol[:,2], alpha=0.2, s=100)
#for evt in wrong_class_evt_numu:
#    plot_x_evt(evt)
evt=next(gen)
plot_x_evt(18)
print(evt)
ax.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
#ax.view_init(30, 60)
plt.show()
# Out:
# 1
# 32

# %%
from lattice_doms_znewk import lattice_doms

# %%
% matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,10))
ax = Axes3D(fig)
ax.scatter(lol[:,0], lol[:,1], lol[:,2], alpha=0.2, s=100)
plot_x_evt(29)
ax.grid()
ax.set_xlabel('x_index')
ax.set_ylabel('y_index')
ax.set_zlabel('z_index')
#ax.view_init(30, 60)
plt.show()
# Out:
# 0

# %%
% matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,10))
ax = Axes3D(fig)
ax.scatter(lol[:,0], lol[:,1], lol[:,2], alpha=0.2, s=100)
plot_x_evt(4)
ax.grid()
ax.set_xlabel('x_index')
ax.set_ylabel('y_index')
ax.set_zlabel('z_index')
#ax.view_init(30, 60)
plt.show()
# Out:
# 1

# %%
np.load("/data/km3net/Xy_multi_data_files/train_test_files/numu_nue_stratified_labels/Xy_indx1_sel5_doms.npz")["test"][29]
# Out:
# 2408

# %%
np.load("/data/km3net/Xy_multi_data_files/train_test_files/numu_nue_stratified_labels/Xy_indx1_sel5_doms.npz")["test"].shape
# Out:
# (508,)

# %%
np.sum(np.load("/data/km3net/Xy_multi_data_files/numu_1_sel5_doms_map.npz")["id"])
# Out:
# 1472

# %%
1008, 777, 2408

# %%
2408-1472
# Out:
# 936

# %%
np.sum(np.load("/data/km3net/Xy_multi_data_files/nue_1_sel_5_doms_map.npz")["id"])
# Out:
# 1065
